# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("C:/Users/ADMIN/Desktop/FBS/Data Science/Data sets/Heart.csv")

# %%
dataset
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
dataset['AHD'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dataset['AHD'].nunique()
# Out:
# 2

# %%
dataset['AHD'].value_counts()
# Out:
# AHD
# No     164
# Yes    139
# Name: count, dtype: int64

# %%
dataset.isna().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset.isna().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          0
# AHD           0
# dtype: int64

# %%
dataset.shape
# Out:
# (297, 15)

# %%
dataset.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
plt.boxplot(dataset['Age'])
plt.show()

# %%
plt.boxplot(dataset['Sex'])
plt.show()

# %%
plt.boxplot(dataset['RestBP'])
plt.show()

# %%
plt.boxplot(dataset['Chol'])
plt.show()

# %%
plt.boxplot(dataset['Fbs'])
plt.show()

# %%
plt.boxplot(dataset['RestECG'])
plt.show()

# %%
plt.boxplot(dataset['MaxHR'])
plt.show()

# %%
plt.boxplot(dataset['ExAng'])
plt.show()

# %%
plt.boxplot(dataset['Oldpeak'])
plt.show()

# %%
plt.boxplot(dataset['Slope'])
plt.show()

# %%
plt.boxplot(dataset['Ca'])
plt.show()

# %%
sns.heatmap(dataset[["Age", "RestBP", "Chol", "RestECG", "MaxHR", "ExAng", "Oldpeak", "Slope", "Ca"]].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Encoding

# %%
dataset.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset["ChestPain"]= le.fit_transform(dataset["ChestPain"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset["Thal"]= le.fit_transform(dataset["Thal"])

# %%
dataset.head()
# Out:
#    Unnamed: 0  Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0           1   63    1          3     145   233    1        2    150      0
# 1           2   67    1          0     160   286    0        2    108      1
# 2           3   67    1          0     120   229    0        2    129      1
# 3           4   37    1          1     130   250    0        0    187      0
# 4           5   41    0          2     130   204    0        2    172      0
#
#    Oldpeak  Slope   Ca  Thal  AHD
# 0      2.3      3  0.0     0   No
# 1      1.5      2  3.0     1  Yes
# 2      2.6      2  2.0     2  Yes
# 3      3.5      3  0.0     1   No
# 4      1.4      1  0.0     1   No

# %% [markdown]
# ### Divide X & Y

# %%
x = dataset.iloc[:,:-1]
y = dataset["AHD"]

# %%
x
# Out:
#      Unnamed: 0  Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1          3     145   233    1        2    150
# 1             2   67    1          0     160   286    0        2    108
# 2             3   67    1          0     120   229    0        2    129
# 3             4   37    1          1     130   250    0        0    187
# 4             5   41    0          2     130   204    0        2    172
# ..          ...  ...  ...        ...     ...   ...  ...      ...    ...
# 297         298   57    0          0     140   241    0        0    123
# 298         299   45    1          3     110   264    0        0    132
# 299         300   68    1          0     144   193    1        0    141
# 300         301   57    1          0     130   131    0        0    115
# 301         302   57    0          2     130   236    0        2    174
#
#      ExAng  Oldpeak  Slope   Ca  Thal
# 0        0      2.3      3  0.0     0
# ...

# %% [markdown]
# ### Build model

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=20)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(dt,feature_names=x.columns,class_names=y.unique(),filled=True)
plt.show()

# %% [markdown]
# ### Check Accuracy

# %%
test_pred = dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test,test_pred)
# Out:
# 0.75

# %%
confusion_matrix(y_test,test_pred)
# Out:
# array([[24,  8],
#        [ 7, 21]])

# %%
train_pred = dt.predict(X_train)
accuracy_score(y_train,train_pred)
# Out:
# 1.0
